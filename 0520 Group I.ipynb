# %%
import pandas as pd
df = pd.read_csv("C:/Users/huang/Desktop/UKPLANT.csv", skiprows=2)

df.info()
df_selected = df[["MARKET", "CATEGORY", "TYPE OF REFORMED MEAT","TYPE OF SAVOURY INGREDIENTS","MAT 18 end week42","MAT 19 end week42","MAT20 end week42"]]
df_selected.info()
df_selected.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MARKET                       163 non-null    object
#  1   CATEGORY                     163 non-null    object
#  2   TYPE OF REFORMED MEAT        160 non-null    object
#  3   TYPE OF SAVOURY INGREDIENTS  114 non-null    object
#  4   MAT 18 end week42            163 non-null    object
#  5   MAT 19 end week42            163 non-null    object
#  6   MAT20 end week42             163 non-null    object
#  7   MAT 18 end week42.1          163 non-null    object
#  8   MAT 19 end week42.1          163 non-null    object
#  9   MAT20 end week42.1           163 non-null    object
#  10  MAT 18 end week42.2          163 non-null    object
#  11  MAT 19 end week42.2          163 non-null    object
#  12  MAT20 end week42.2           163 non-null    object
# ...
